# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
webpage = requests.get("https://pubmed.ncbi.nlm.nih.gov/trending/?filter=simsearch2.ffrft").text

# %%
soup = BeautifulSoup(webpage, 'lxml')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head itemscope="" itemtype="http://schema.org/WebPage" prefix="og: http://ogp.me/ns#">
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <!-- Mobile properties -->
#   <meta content="True" name="HandheldFriendly"/>
#   <meta content="320" name="MobileOptimized"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <link href="https://cdn.ncbi.nlm.nih.gov" rel="preconnect"/>
#   <link href="https://www.ncbi.nlm.nih.gov" rel="preconnect"/>
#   <link href="https://www.google-analytics.com" rel="preconnect"/>
#   <link href="https://cdn.ncbi.nlm.nih.gov/pubmed/894284df-7f59-4b5d-9419-e48621fd0afc/CACHE/css/output.5ecf62baa0fa.css" rel="stylesheet" type="text/css"/>
#   <link href="https://cdn.ncbi.nlm.nih.gov/pubmed/894284df-7f59-4b5d-9419-e48621fd0afc/CACHE/css/output.452c70ce66f7.css" rel="stylesheet" type="text/css"/>
# ...
